# %%
from datetime import datetime
import pandas as pd
import cloudscraper
from bs4 import BeautifulSoup
import base64
import os

# %%
scraper = cloudscraper.create_scraper()

# %%
def get_company_info(company_name):
    df_companies = pd.read_csv('companies.csv')
    company_info = df_companies[df_companies["issuingCompany"] == company_name]
    if company_info.empty:
        raise ValueError(f"Empresa '{company_name}' não encontrada.")
    return company_info.iloc[0]['codeCVM']

# %%
STRUCTURED_REPORTS_URL = "https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListStructuredReports/"
CVM_BASE_URL = "https://www.rad.cvm.gov.br/ENET/"

# %%
def get_structured_reports(code_cvm, year):
    payload = f'{{"codeCVM":{code_cvm},"language":"pt-br","status":true,"year":{year}}}'
    encoded_payload = base64.b64encode(payload.encode()).decode()
    url = STRUCTURED_REPORTS_URL + encoded_payload
    response = scraper.get(url)
    if response.status_code != 200:
        raise Exception(f"Erro na requisição. Status code: {response.status_code}")
    return response.json()

# %%
def extract_url_search(data_json):
    try:
        return data_json["dfp"][0]["urlSearch"]
    except Exception as e:
        print(f"Erro ao extrair URL: {e}")
        return None

# %%
def extract_links_from_select(url_report):
    try:
        response = scraper.get(url_report)
        soup = BeautifulSoup(response.content, "html.parser")
        select = soup.find("select", {"id": "cmbQuadro"})
        options = select.find_all("option")

        script = soup.find_all("script")[-1]
        link_id = script.string.split("location=")[1].split("'")[1].split("Versao=")[1]

        links = {
            option.text: f"{CVM_BASE_URL}{option['value'].replace(' ', '%20')}{link_id}"
            for option in options
        }
        
        responses = {}
        for title, link in links.items():
            try:
                response = scraper.get(link)
                responses[title] = base64.b64encode(response.content).decode('utf-8')
            except Exception as e:
                print(f"Erro ao extrair link: {e}")
                responses[title] = None
        
        return responses
    except Exception as e:
        print(f"Erro ao extrair links: {e}")
        return None

# %%
def get_table_data(content):
    decoded_content = base64.b64decode(content).decode('utf-8')
    soup = BeautifulSoup(decoded_content, "html.parser")
    table = soup.find("table", {"id": "ctl00_cphPopUp_tbDados"})

    if not table:
        raise Exception("Tabela não encontrada no link fornecido.")

    all_tr = table.find_all("tr")
    data = [[td.text.strip() for td in tr.find_all("td")] for tr in all_tr]

    return pd.DataFrame(data[1:], columns=data[0])

# %%
def reorganize_df(df: pd.DataFrame) -> pd.DataFrame:
    df.index = df['Descrição']
    df = df.drop(columns=['Descrição', 'Conta'])
    
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].str.replace('.', '')
            df[column] = df[column].str.replace(',', '.')
            
            df[column] = df[column].apply(pd.to_numeric, errors='coerce')
            df[column] = df[column].fillna(0)
            
    # Verificar se existem index duplicados, caso haja, adicionar '{i}' ao final do index dos duplicados
    if df.index.duplicated().any():
        df.index = df.index + df.groupby(level=0).cumcount().astype(str).replace('0', '')
        
    return df

# %%
def fetch_anual_data(url_report, links, company_name, data_type, year):
    
    if not url_report:
        raise ValueError(f"Não foi possível localizar relatórios para '{company_name}' no ano {year}.")
    
    if not links or data_type not in links:
        raise ValueError(f"Tipo de dado '{data_type}' não disponível para '{company_name}'.")

    response = links[data_type]
    df = get_table_data(response)
    df = reorganize_df(df)
    
    return df

# %%
def fetch_all_anual_data(url_report, links, company_name, year):
    data_types = [
            "Balanço Patrimonial Ativo",
            "Balanço Patrimonial Passivo",
            "Demonstração do Resultado",
            "Demonstração do Resultado Abrangente",
            "Demonstração do Fluxo de Caixa",
            "Demonstração de Valor Adicionado",
    ]
    data = {}
    for data_type in data_types:
        try:
            df = fetch_anual_data(url_report, links, company_name, data_type, year)
            data[data_type] = df
        except Exception as e:
            print(f"Erro ao extrair dados de '{data_type}': {e}")
            data[data_type] = None
    return data

# %%
def get_all_itrs_links(data_json):
        itr_links = {}
        try:
            itr = data_json['itr']
            for i in itr:
                date = i['dateTimeReference'].split('T')[0]
                itr_links[date] = i['urlSearch']
                
            return itr_links
        except Exception as e:
            print("Erro ao extrair links de ITR.")
            return itr_links

# %%
def transform_data(data: dict, year_rec) -> dict:
        for key in data.keys():
            if key in ['Balanço Patrimonial Ativo', 'Balanço Patrimonial Passivo']:
                for column in data[key].columns:
                    year = column.split('/')[-1]
                    if year != year_rec:
                        new_column = f'01/01/{year}  a  31/12/{year}'
                        data[key].rename(columns={column: new_column}, inplace=True)
                    else:
                        new_column = f'01/01/{year}  a  {column}'
                        data[key].rename(columns={column: new_column}, inplace=True)
            
        return data

# %%
def fetch_itr_data(url_report, dfp_links ,itr_links, company_name, year):
    if not itr_links:
        raise ValueError("Não foi possível localizar relatórios ITR.")
    
    itr_data = {}
    
    for date, link in itr_links.items():
        itr_data[date] = fetch_all_anual_data(link, extract_links_from_select(link), company_name, year)
    
    end_year = fetch_all_anual_data(url_report, dfp_links, company_name, year + 1)
    formated_date = f'{year}-12-31'
    
    itr_data[formated_date] = end_year
    for key in itr_data.keys():
        itr_data[key] = transform_data(itr_data[key], year)
        
    return itr_data

# %%
code_cvm = get_company_info("PETR")

# %%
strcuted_reports_response = get_structured_reports(code_cvm, 2023)

# %%
url_report = extract_url_search(strcuted_reports_response)

# %%
dfp_links = extract_links_from_select(url_report)

# %%
itr_links = get_all_itrs_links(strcuted_reports_response)

# %%
test = fetch_itr_data(url_report, dfp_links, itr_links, "PETR", 2022)

# %%
def convert_df_to_dict(data: dict) -> dict:
    for key in data.keys():
        if data[key] is not None:
            for k in data[key].keys():
                if data[key][k] is not None:
                    data[key][k] = data[key][k].to_dict()
    return data

# %%
m = convert_df_to_dict(test.copy())

# %%
# Out:
# {'2023-09-30': {'Balanço Patrimonial Ativo': {'01/01/2023  a  31/12/2023': {'Ativo Total': 1025496000.0,
#     'Ativo Circulante': 147311000.0,
#     'Caixa e Equivalentes de Caixa': 60642000.0,
#     'Aplicações Financeiras': 6505000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0,
#     'Títulos para Negociação': 0.0,
#     'Títulos Designados a Valor Justo': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0,
#     'Contas a Receber': 25502000.0,
#     'Clientes': 0.0,
#     'Outras Contas a Receber': 0.0,
#     'Estoques': 39510000.0,
#     'Ativos Biológicos': 0.0,
#     'Tributos a Recuperar': 5965000.0,
#     'Tributos Correntes a Recuperar': 5965000.0,
#     'Imposto de renda e contribuição social': 1034000.0,
#     'Impostos e contribuições': 4931000.0,
#     'Despesas Antecipadas': 0.0,
#     'Outros Ativos Circulantes': 9187000.0,
#     'Ativos Não-Correntes a Venda': 295000.0,
#     'Ativos de Operações Descontinuadas': 0.0,
#     'Outros': 8892000.0,
#     'Depósitos Vinculados a Class Action': 0.0,
#     'Adiantamento a fornecedores': 0.0,
#     'Outros ativos': 8892000.0,
#     'Ativo Não Circulante': 878185000.0,
#     'Ativo Realizável a Longo Prazo': 131247000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado1': 0.0,
#     'Títulos Designados a Valor Justo1': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes1': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado1': 19600000.0,
#     'Contas a Receber1': 7795000.0,
#     'Clientes1': 0.0,
#     'Outras Contas a Receber1': 0.0,
#     'Estoques1': 0.0,
#     'Ativos Biológicos1': 0.0,
#     'Tributos Diferidos': 26185000.0,
#     'Imposto de renda e contribuição social diferidos': 4916000.0,
#     'Impostos e contribuições1': 21269000.0,
#     'Despesas Antecipadas1': 0.0,
#     'Créditos com Partes Relacionadas': 0.0,
#     'Créditos com Coligadas': 0.0,
#     'Créditos com Controladores': 0.0,
#     'Créditos com Outras Partes Relacionadas': 0.0,
#     'Outros Ativos Não Circulantes': 77667000.0,
#     'Ativos Não-Correntes a Venda1': 0.0,
#     'Ativos de Operações Descontinuadas1': 0.0,
#     'Adiantamento a fornecedores1': 0.0,
#     'Depósitos judiciais': 67213000.0,
#     'Outros ativos1': 10454000.0,
#     'Investimentos': 6879000.0,
#     'Participações Societárias': 0.0,
#     'Participações em Coligadas': 0.0,
#     'Participações em Controladas em Conjunto': 0.0,
#     'Outros Investimentos': 0.0,
#     'Propriedades para Investimento': 0.0,
#     'Imobilizado': 725456000.0,
#     'Imobilizado em Operação': 0.0,
#     'Direito de Uso em Arrendamento': 0.0,
#     'Imobilizado em Andamento': 0.0,
#     'Intangível': 14603000.0,
#     'Intangíveis': 0.0,
#     'Contrato de Concessão': 0.0,
#     'Goodwill': 0.0},
#    '01/01/2022  a  31/12/2022': {'Ativo Total': 976709000.0,
#     'Ativo Circulante': 163052000.0,
#     'Caixa e Equivalentes de Caixa': 41723000.0,
#     'Aplicações Financeiras': 14470000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0,
#     'Títulos para Negociação': 0.0,
#     'Títulos Designados a Valor Justo': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0,
#     'Contas a Receber': 26142000.0,
#     'Clientes': 0.0,
#     'Outras Contas a Receber': 0.0,
#     'Estoques': 45804000.0,
#     'Ativos Biológicos': 0.0,
#     'Tributos a Recuperar': 6819000.0,
#     'Tributos Correntes a Recuperar': 6819000.0,
#     'Imposto de renda e contribuição social': 859000.0,
#     'Impostos e contribuições': 5960000.0,
#     'Despesas Antecipadas': 0.0,
#     'Outros Ativos Circulantes': 28094000.0,
#     'Ativos Não-Correntes a Venda': 18823000.0,
#     'Ativos de Operações Descontinuadas': 0.0,
#     'Outros': 9271000.0,
#     'Depósitos Vinculados a Class Action': 0.0,
#     'Adiantamento a fornecedores': 0.0,
#     'Outros ativos': 9271000.0,
#     'Ativo Não Circulante': 813657000.0,
#     'Ativo Realizável a Longo Prazo': 110722000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado1': 0.0,
#     'Títulos Designados a Valor Justo1': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes1': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado1': 8159000.0,
#     'Contas a Receber1': 12729000.0,
#     'Clientes1': 0.0,
#     'Outras Contas a Receber1': 0.0,
#     'Estoques1': 0.0,
#     'Ativos Biológicos1': 0.0,
#     'Tributos Diferidos': 24057000.0,
#     'Imposto de renda e contribuição social diferidos': 4342000.0,
#     'Impostos e contribuições1': 19715000.0,
#     'Despesas Antecipadas1': 0.0,
#     'Créditos com Partes Relacionadas': 0.0,
#     'Créditos com Coligadas': 0.0,
#     'Créditos com Controladores': 0.0,
#     'Créditos com Outras Partes Relacionadas': 0.0,
#     'Outros Ativos Não Circulantes': 65777000.0,
#     'Ativos Não-Correntes a Venda1': 0.0,
#     'Ativos de Operações Descontinuadas1': 0.0,
#     'Adiantamento a fornecedores1': 0.0,
#     'Depósitos judiciais': 57671000.0,
#     'Outros ativos1': 8106000.0,
#     'Investimentos': 8172000.0,
#     'Participações Societárias': 0.0,
#     'Participações em Coligadas': 0.0,
#     'Participações em Controladas em Conjunto': 0.0,
#     'Outros Investimentos': 0.0,
#     'Propriedades para Investimento': 0.0,
#     'Imobilizado': 679182000.0,
#     'Imobilizado em Operação': 0.0,
#     'Direito de Uso em Arrendamento': 0.0,
#     'Imobilizado em Andamento': 0.0,
#     'Intangível': 15581000.0,
#     'Intangíveis': 0.0,
#     'Contrato de Concessão': 0.0,
#     'Goodwill': 0.0}},
#   'Balanço Patrimonial Passivo': {'01/01/2023  a  31/12/2023': {'Passivo Total': 1025496000.0,
#     'Passivo Circulante': 154571000.0,
#     'Obrigações Sociais e Trabalhistas': 8839000.0,
#     'Obrigações Sociais': 0.0,
#     'Obrigações Trabalhistas': 0.0,
#     'Fornecedores': 23383000.0,
#     'Fornecedores Nacionais': 0.0,
#     'Fornecedores Estrangeiros': 0.0,
#     'Obrigações Fiscais': 8085000.0,
#     'Obrigações Fiscais Federais': 8085000.0,
#     'Imposto de Renda e Contribuição Social a Pagar': 8085000.0,
#     'Obrigações Fiscais Estaduais': 0.0,
#     'Obrigações Fiscais Municipais': 0.0,
#     'Empréstimos e Financiamentos': 55139000.0,
#     'Empréstimos e Financiamentos1': 21935000.0,
#     'Em Moeda Nacional': 0.0,
#     'Em Moeda Estrangeira': 0.0,
#     'Debêntures': 0.0,
#     'Financiamento por Arrendamento': 33204000.0,
#     'Outras Obrigações': 54775000.0,
#     'Passivos com Partes Relacionadas': 0.0,
#     'Débitos com Coligadas': 0.0,
#     'Débitos com Controladores': 0.0,
#     'Débitos com Outras Partes Relacionadas': 0.0,
#     'Outros': 54775000.0,
#     'Dividendos e JCP a Pagar': 21694000.0,
#     'Dividendo Mínimo Obrigatório a Pagar': 0.0,
#     'Obrigações por Pagamentos Baseados em Ações': 0.0,
#     'Impostos e contribuições': 19225000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': 13856000.0,
#     'Provisões': 3802000.0,
#     'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis': 0.0,
#     'Provisões Fiscais': 0.0,
#     'Provisões Previdenciárias e Trabalhistas': 0.0,
#     'Provisões para Benefícios a Empregados': 0.0,
#     'Provisões Cíveis': 0.0,
#     'Outras Provisões': 3802000.0,
#     'Provisões para Garantias': 0.0,
#     'Provisões para Reestruturação': 0.0,
#     'Provisões para Passivos Ambientais e de Desativação': 0.0,
#     'Plano de pensão e de saúde': 3802000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados': 548000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda': 548000.0,
#     'Passivos sobre Ativos de Operações Descontinuadas': 0.0,
#     'Passivo Não Circulante': 483435000.0,
#     'Empréstimos e Financiamentos2': 250312000.0,
#     'Empréstimos e Financiamentos3': 125603000.0,
#     'Em Moeda Nacional1': 0.0,
#     'Em Moeda Estrangeira1': 0.0,
#     'Debêntures1': 0.0,
#     'Financiamento por Arrendamento1': 124709000.0,
#     'Outras Obrigações1': 1484000.0,
#     'Passivos com Partes Relacionadas1': 0.0,
#     'Débitos com Coligadas1': 0.0,
#     'Débitos com Controladores1': 0.0,
#     'Débitos com Outras Partes Relacionadas1': 0.0,
#     'Outros1': 1484000.0,
#     'Obrigações por Pagamentos Baseados em Ações1': 0.0,
#     'Adiantamento para Futuro Aumento de Capital': 0.0,
#     'Imposto de renda e contribuição social': 1484000.0,
#     'Tributos Diferidos': 50932000.0,
#     'Imposto de Renda e Contribuição Social Diferidos': 50932000.0,
#     'Provisões1': 180707000.0,
#     'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis1': 16850000.0,
#     'Provisões Fiscais1': 0.0,
#     'Provisões Previdenciárias e Trabalhistas1': 0.0,
#     'Provisões para Benefícios a Empregados1': 0.0,
#     'Provisões Cíveis1': 0.0,
#     'Outras Provisões1': 163857000.0,
#     'Provisões para Garantias1': 0.0,
#     'Provisões para Reestruturação1': 0.0,
#     'Provisões para Passivos Ambientais e de Desativação1': 0.0,
#     'Plano de pensão e de saúde1': 57811000.0,
#     'Provisão para desmantelamento de áreas': 96166000.0,
#     'Salários, férias, encargos e participações': 510000.0,
#     'Outros passivos1': 9370000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados1': 0.0,
#     'Passivos sobre Ativos Não-Correntes a Venda1': 0.0,
#     'Passivos sobre Ativos de Operações Descontinuadas1': 0.0,
#     'Lucros e Receitas a Apropriar': 0.0,
#     'Lucros a Apropriar': 0.0,
#     'Receitas a Apropriar': 0.0,
#     'Subvenções de Investimento a Apropriar': 0.0,
#     'Patrimônio Líquido Consolidado': 387490000.0,
#     'Capital Social Realizado': 205432000.0,
#     'Reservas de Capital': 2131000.0,
#     'Ágio na Emissão de Ações': 0.0,
#     'Reserva Especial de Ágio na Incorporação': 0.0,
#     'Alienação de Bônus de Subscrição': 0.0,
#     'Opções Outorgadas': 0.0,
#     'Ações em Tesouraria': 0.0,
#     'Adiantamento para Futuro Aumento de Capital1': 0.0,
#     'Reservas de Reavaliação': 0.0,
#     'Reservas de Lucros': 146422000.0,
#     'Reserva Legal': 0.0,
#     'Reserva Estatutária': 0.0,
#     'Reserva para Contingências': 0.0,
#     'Reserva de Lucros a Realizar': 0.0,
#     'Reserva de Retenção de Lucros': 0.0,
#     'Reserva Especial para Dividendos Não Distribuídos': 0.0,
#     'Reserva de Incentivos Fiscais': 0.0,
#     'Dividendo Adicional Proposto': 0.0,
#     'Ações em Tesouraria1': 0.0,
#     'Lucros/Prejuízos Acumulados': 0.0,
#     'Ajustes de Avaliação Patrimonial': 0.0,
#     'Ajustes Acumulados de Conversão': 0.0,
#     'Outros Resultados Abrangentes': 32022000.0,
#     'Participação dos Acionistas Não Controladores': 1483000.0},
#    '01/01/2022  a  31/12/2022': {'Passivo Total': 976709000.0,
#     'Passivo Circulante': 163731000.0,
#     'Obrigações Sociais e Trabalhistas': 7805000.0,
#     'Obrigações Sociais': 0.0,
#     'Obrigações Trabalhistas': 0.0,
#     'Fornecedores': 28507000.0,
#     'Fornecedores Nacionais': 0.0,
#     'Fornecedores Estrangeiros': 0.0,
#     'Obrigações Fiscais': 15045000.0,
#     'Obrigações Fiscais Federais': 15045000.0,
#     'Imposto de Renda e Contribuição Social a Pagar': 15045000.0,
#     'Obrigações Fiscais Estaduais': 0.0,
#     'Obrigações Fiscais Municipais': 0.0,
#     'Empréstimos e Financiamentos': 47650000.0,
#     'Empréstimos e Financiamentos1': 18656000.0,
#     'Em Moeda Nacional': 0.0,
#     'Em Moeda Estrangeira': 0.0,
#     'Debêntures': 0.0,
#     'Financiamento por Arrendamento': 28994000.0,
#     'Outras Obrigações': 53328000.0,
#     'Passivos com Partes Relacionadas': 0.0,
#     'Débitos com Coligadas': 0.0,
#     'Débitos com Controladores': 0.0,
#     'Débitos com Outras Partes Relacionadas': 0.0,
#     'Outros': 53328000.0,
#     'Dividendos e JCP a Pagar': 21762000.0,
#     'Dividendo Mínimo Obrigatório a Pagar': 0.0,
#     'Obrigações por Pagamentos Baseados em Ações': 0.0,
#     'Impostos e contribuições': 15906000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': 15660000.0,
#     'Provisões': 3750000.0,
#     'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis': 0.0,
#     'Provisões Fiscais': 0.0,
#     'Provisões Previdenciárias e Trabalhistas': 0.0,
#     'Provisões para Benefícios a Empregados': 0.0,
#     'Provisões Cíveis': 0.0,
#     'Outras Provisões': 3750000.0,
#     'Provisões para Garantias': 0.0,
#     'Provisões para Reestruturação': 0.0,
#     'Provisões para Passivos Ambientais e de Desativação': 0.0,
#     'Plano de pensão e de saúde': 3750000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados': 7646000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda': 7646000.0,
#     'Passivos sobre Ativos de Operações Descontinuadas': 0.0,
#     'Passivo Não Circulante': 448593000.0,
#     'Empréstimos e Financiamentos2': 233053000.0,
#     'Empréstimos e Financiamentos3': 137630000.0,
#     'Em Moeda Nacional1': 0.0,
#     'Em Moeda Estrangeira1': 0.0,
#     'Debêntures1': 0.0,
#     'Financiamento por Arrendamento1': 95423000.0,
#     'Outras Obrigações1': 1578000.0,
#     'Passivos com Partes Relacionadas1': 0.0,
#     'Débitos com Coligadas1': 0.0,
#     'Débitos com Controladores1': 0.0,
#     'Débitos com Outras Partes Relacionadas1': 0.0,
#     'Outros1': 1578000.0,
#     'Obrigações por Pagamentos Baseados em Ações1': 0.0,
#     'Adiantamento para Futuro Aumento de Capital': 0.0,
#     'Imposto de renda e contribuição social': 1578000.0,
#     'Tributos Diferidos': 35220000.0,
#     'Imposto de Renda e Contribuição Social Diferidos': 35220000.0,
#     'Provisões1': 178742000.0,
#     'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis1': 15703000.0,
#     'Provisões Fiscais1': 0.0,
#     'Provisões Previdenciárias e Trabalhistas1': 0.0,
#     'Provisões para Benefícios a Empregados1': 0.0,
#     'Provisões Cíveis1': 0.0,
#     'Outras Provisões1': 163039000.0,
#     'Provisões para Garantias1': 0.0,
#     'Provisões para Reestruturação1': 0.0,
#     'Provisões para Passivos Ambientais e de Desativação1': 0.0,
#     'Plano de pensão e de saúde1': 54925000.0,
#     'Provisão para desmantelamento de áreas': 97048000.0,
#     'Salários, férias, encargos e participações': 776000.0,
#     'Outros passivos1': 10290000.0,
#     'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados1': 0.0,
#     'Passivos sobre Ativos Não-Correntes a Venda1': 0.0,
#     'Passivos sobre Ativos de Operações Descontinuadas1': 0.0,
#     'Lucros e Receitas a Apropriar': 0.0,
#     'Lucros a Apropriar': 0.0,
#     'Receitas a Apropriar': 0.0,
#     'Subvenções de Investimento a Apropriar': 0.0,
#     'Patrimônio Líquido Consolidado': 364385000.0,
#     'Capital Social Realizado': 205432000.0,
#     'Reservas de Capital': 3102000.0,
#     'Ágio na Emissão de Ações': 0.0,
#     'Reserva Especial de Ágio na Incorporação': 0.0,
#     'Alienação de Bônus de Subscrição': 0.0,
#     'Opções Outorgadas': 0.0,
#     'Ações em Tesouraria': 0.0,
#     'Adiantamento para Futuro Aumento de Capital1': 0.0,
#     'Reservas de Reavaliação': 0.0,
#     'Reservas de Lucros': 128562000.0,
#     'Reserva Legal': 0.0,
#     'Reserva Estatutária': 0.0,
#     'Reserva para Contingências': 0.0,
#     'Reserva de Lucros a Realizar': 0.0,
#     'Reserva de Retenção de Lucros': 0.0,
#     'Reserva Especial para Dividendos Não Distribuídos': 0.0,
#     'Reserva de Incentivos Fiscais': 0.0,
#     'Dividendo Adicional Proposto': 0.0,
#     'Ações em Tesouraria1': 0.0,
#     'Lucros/Prejuízos Acumulados': 0.0,
#     'Ajustes de Avaliação Patrimonial': 0.0,
#     'Ajustes Acumulados de Conversão': 0.0,
#     'Outros Resultados Abrangentes': 25498000.0,
#     'Participação dos Acionistas Não Controladores': 1791000.0}},
#   'Demonstração do Resultado': {'01/07/2023\xa0\xa0a\xa0\xa030/09/2023': {'Receita de Venda de Bens e/ou Serviços': 124828000.0,
#     'Custo dos Bens e/ou Serviços Vendidos': -58513000.0,
#     'Resultado Bruto': 66315000.0,
#     'Despesas/Receitas Operacionais': -18769000.0,
#     'Despesas com Vendas': -6289000.0,
#     'Despesas Gerais e Administrativas': -1927000.0,
#     'Perdas pela Não Recuperabilidade de Ativos': 0.0,
#     'Outras Receitas Operacionais': 0.0,
#     'Outras Despesas Operacionais': -9341000.0,
#     'Tributárias': -557000.0,
#     'Custos com pesquisa e desenvolvimento tecnológico': -908000.0,
#     'Custos exploratórios para extração de petróleo e gás': -2364000.0,
#     'Participação nos Lucros ou Resultados': 0.0,
#     'Outras receitas (despesas) operacionais líquidas': -5126000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Reversão (Perda) no valor de recuperação de ativos - Impairment': -386000.0,
#     'Resultado de Equivalência Patrimonial': -1212000.0,
#     'Resultado Antes do Resultado Financeiro e dos Tributos': 47546000.0,
#     'Resultado Financeiro': -9760000.0,
#     'Receitas Financeiras': 2934000.0,
#     'Receitas financeiras': 2934000.0,
#     'Variações Monetárias e Cambiais Líquidas': 0.0,
#     'Despesas Financeiras': -12694000.0,
#     'Despesas financeiras': -5680000.0,
#     'Variações monetárias e cambiais, líquidas': -7014000.0,
#     'Resultado Antes dos Tributos sobre o Lucro': 37786000.0,
#     'Imposto de Renda e Contribuição Social sobre o Lucro': -11026000.0,
#     'Corrente': -12531000.0,
#     'Diferido': 1505000.0,
#     'Resultado Líquido das Operações Continuadas': 26760000.0,
#     'Resultado Líquido de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Líquido das Operações Descontinuadas': 0.0,
#     'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Consolidado do Período': 26760000.0,
#     'Atribuído a Sócios da Empresa Controladora': 26625000.0,
#     'Atribuído a Sócios Não Controladores': 135000.0,
#     'Lucro por Ação - (Reais / Ação)': 0.0,
#     'Lucro Básico por Ação': 0.0,
#     'ON': 2.04,
#     'PN': 2.04,
#     'Lucro Diluído por Ação': 0.0,
#     'ON1': 2.04,
#     'PN1': 2.04},
#    '01/01/2023\xa0\xa0a\xa0\xa030/09/2023': {'Receita de Venda de Bens e/ou Serviços': 377736000.0,
#     'Custo dos Bens e/ou Serviços Vendidos': -180429000.0,
#     'Resultado Bruto': 197307000.0,
#     'Despesas/Receitas Operacionais': -47593000.0,
#     'Despesas com Vendas': -18580000.0,
#     'Despesas Gerais e Administrativas': -5703000.0,
#     'Perdas pela Não Recuperabilidade de Ativos': 0.0,
#     'Outras Receitas Operacionais': 0.0,
#     'Outras Despesas Operacionais': -22173000.0,
#     'Tributárias': -3228000.0,
#     'Custos com pesquisa e desenvolvimento tecnológico': -2558000.0,
#     'Custos exploratórios para extração de petróleo e gás': -4126000.0,
#     'Participação nos Lucros ou Resultados': 0.0,
#     'Outras receitas (despesas) operacionais líquidas': -9913000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Reversão (Perda) no valor de recuperação de ativos - Impairment': -2348000.0,
#     'Resultado de Equivalência Patrimonial': -1137000.0,
#     'Resultado Antes do Resultado Financeiro e dos Tributos': 149714000.0,
#     'Resultado Financeiro': -13229000.0,
#     'Receitas Financeiras': 7906000.0,
#     'Receitas financeiras': 7906000.0,
#     'Variações Monetárias e Cambiais Líquidas': 0.0,
#     'Despesas Financeiras': -21135000.0,
#     'Despesas financeiras': -14362000.0,
#     'Variações monetárias e cambiais, líquidas': -6773000.0,
#     'Resultado Antes dos Tributos sobre o Lucro': 136485000.0,
#     'Imposto de Renda e Contribuição Social sobre o Lucro': -42482000.0,
#     'Corrente': -36486000.0,
#     'Diferido': -5996000.0,
#     'Resultado Líquido das Operações Continuadas': 94003000.0,
#     'Resultado Líquido de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Líquido das Operações Descontinuadas': 0.0,
#     'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Consolidado do Período': 94003000.0,
#     'Atribuído a Sócios da Empresa Controladora': 93563000.0,
#     'Atribuído a Sócios Não Controladores': 440000.0,
#     'Lucro por Ação - (Reais / Ação)': 0.0,
#     'Lucro Básico por Ação': 0.0,
#     'ON': 7.17,
#     'PN': 7.17,
#     'Lucro Diluído por Ação': 0.0,
#     'ON1': 7.17,
#     'PN1': 7.17},
#    '01/07/2022\xa0\xa0a\xa0\xa030/09/2022': {'Receita de Venda de Bens e/ou Serviços': 170076000.0,
#     'Custo dos Bens e/ou Serviços Vendidos': -83240000.0,
#     'Resultado Bruto': 86836000.0,
#     'Despesas/Receitas Operacionais': -12224000.0,
#     'Despesas com Vendas': -6358000.0,
#     'Despesas Gerais e Administrativas': -1752000.0,
#     'Perdas pela Não Recuperabilidade de Ativos': 0.0,
#     'Outras Receitas Operacionais': 0.0,
#     'Outras Despesas Operacionais': -4285000.0,
#     'Tributárias': -489000.0,
#     'Custos com pesquisa e desenvolvimento tecnológico': -984000.0,
#     'Custos exploratórios para extração de petróleo e gás': -565000.0,
#     'Participação nos Lucros ou Resultados': 0.0,
#     'Outras receitas (despesas) operacionais líquidas': -911000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Reversão (Perda) no valor de recuperação de ativos - Impairment': -1336000.0,
#     'Resultado de Equivalência Patrimonial': 171000.0,
#     'Resultado Antes do Resultado Financeiro e dos Tributos': 74612000.0,
#     'Resultado Financeiro': -7973000.0,
#     'Receitas Financeiras': 2713000.0,
#     'Receitas financeiras': 2713000.0,
#     'Variações Monetárias e Cambiais Líquidas': 0.0,
#     'Despesas Financeiras': -10686000.0,
#     'Despesas financeiras': -4157000.0,
#     'Variações monetárias e cambiais, líquidas': -6529000.0,
#     'Resultado Antes dos Tributos sobre o Lucro': 66639000.0,
#     'Imposto de Renda e Contribuição Social sobre o Lucro': -20403000.0,
#     'Corrente': -19181000.0,
#     'Diferido': -1222000.0,
#     'Resultado Líquido das Operações Continuadas': 46236000.0,
#     'Resultado Líquido de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Líquido das Operações Descontinuadas': 0.0,
#     'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Consolidado do Período': 46236000.0,
#     'Atribuído a Sócios da Empresa Controladora': 46096000.0,
#     'Atribuído a Sócios Não Controladores': 140000.0,
#     'Lucro por Ação - (Reais / Ação)': 0.0,
#     'Lucro Básico por Ação': 0.0,
#     'ON': 3.54,
#     'PN': 3.54,
#     'Lucro Diluído por Ação': 0.0,
#     'ON1': 3.54,
#     'PN1': 3.54},
#    '01/01/2022\xa0\xa0a\xa0\xa030/09/2022': {'Receita de Venda de Bens e/ou Serviços': 482677000.0,
#     'Custo dos Bens e/ou Serviços Vendidos': -225214000.0,
#     'Resultado Bruto': 257463000.0,
#     'Despesas/Receitas Operacionais': -21019000.0,
#     'Despesas com Vendas': -18653000.0,
#     'Despesas Gerais e Administrativas': -4900000.0,
#     'Perdas pela Não Recuperabilidade de Ativos': 0.0,
#     'Outras Receitas Operacionais': 0.0,
#     'Outras Despesas Operacionais': 601000.0,
#     'Tributárias': -1255000.0,
#     'Custos com pesquisa e desenvolvimento tecnológico': -3145000.0,
#     'Custos exploratórios para extração de petróleo e gás': -1169000.0,
#     'Participação nos Lucros ou Resultados': 0.0,
#     'Outras receitas (despesas) operacionais líquidas': 8349000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Reversão (Perda) no valor de recuperação de ativos - Impairment': -2179000.0,
#     'Resultado de Equivalência Patrimonial': 1933000.0,
#     'Resultado Antes do Resultado Financeiro e dos Tributos': 236444000.0,
#     'Resultado Financeiro': -20747000.0,
#     'Receitas Financeiras': 7127000.0,
#     'Receitas financeiras': 7127000.0,
#     'Variações Monetárias e Cambiais Líquidas': 0.0,
#     'Despesas Financeiras': -27874000.0,
#     'Despesas financeiras': -12817000.0,
#     'Variações monetárias e cambiais, líquidas': -15057000.0,
#     'Resultado Antes dos Tributos sobre o Lucro': 215697000.0,
#     'Imposto de Renda e Contribuição Social sobre o Lucro': -70194000.0,
#     'Corrente': -58701000.0,
#     'Diferido': -11493000.0,
#     'Resultado Líquido das Operações Continuadas': 145503000.0,
#     'Resultado Líquido de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Líquido das Operações Descontinuadas': 0.0,
#     'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Consolidado do Período': 145503000.0,
#     'Atribuído a Sócios da Empresa Controladora': 144987000.0,
#     'Atribuído a Sócios Não Controladores': 516000.0,
#     'Lucro por Ação - (Reais / Ação)': 0.0,
#     'Lucro Básico por Ação': 0.0,
#     'ON': 11.12,
#     'PN': 11.12,
#     'Lucro Diluído por Ação': 0.0,
#     'ON1': 11.12,
#     'PN1': 11.12}},
#   'Demonstração do Resultado Abrangente': {'01/07/2023\xa0\xa0a\xa0\xa030/09/2023': {'Lucro Líquido Consolidado do Período': 26760000.0,
#     'Outros Resultados Abrangentes': 4892000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': 0.0,
#     'IR e CS diferidos s/ ganhos (perdas) atuariais com planos de benefícios definidos': 0.0,
#     'Ajustes de conversão em investidas': 10631000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': -12078000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 3691000.0,
#     'IR e CS diferidos s/ resultados não realizados com hedge de fluxo de caixa': 2851000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': -203000.0,
#     'Resultado Abrangente Consolidado do Período': 31652000.0,
#     'Atribuído a Sócios da Empresa Controladora': 31515000.0,
#     'Atribuído a Sócios Não Controladores': 137000.0},
#    '01/01/2023\xa0\xa0a\xa0\xa030/09/2023': {'Lucro Líquido Consolidado do Período': 94003000.0,
#     'Outros Resultados Abrangentes': 6524000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': -570000.0,
#     'IR e CS diferidos s/ ganhos (perdas) atuariais com planos de benefícios definidos': 194000.0,
#     'Ajustes de conversão em investidas': -11844000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': 12147000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 15020000.0,
#     'IR e CS diferidos s/ resultados não realizados com hedge de fluxo de caixa': -9237000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': 814000.0,
#     'Resultado Abrangente Consolidado do Período': 100527000.0,
#     'Atribuído a Sócios da Empresa Controladora': 100087000.0,
#     'Atribuído a Sócios Não Controladores': 440000.0},
#    '01/07/2022\xa0\xa0a\xa0\xa030/09/2022': {'Lucro Líquido Consolidado do Período': 46236000.0,
#     'Outros Resultados Abrangentes': 5757000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': 0.0,
#     'IR e CS diferidos s/ ganhos (perdas) atuariais com planos de benefícios definidos': 0.0,
#     'Ajustes de conversão em investidas': 8939000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': -10442000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 5813000.0,
#     'IR e CS diferidos s/ resultados não realizados com hedge de fluxo de caixa': 1574000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': -127000.0,
#     'Resultado Abrangente Consolidado do Período': 51993000.0,
#     'Atribuído a Sócios da Empresa Controladora': 51852000.0,
#     'Atribuído a Sócios Não Controladores': 141000.0},
#    '01/01/2022\xa0\xa0a\xa0\xa030/09/2022': {'Lucro Líquido Consolidado do Período': 145503000.0,
#     'Outros Resultados Abrangentes': 15955000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': 0.0,
#     'IR e CS diferidos s/ ganhos (perdas) atuariais com planos de benefícios definidos': 0.0,
#     'Ajustes de conversão em investidas': -8137000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': 17059000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 18476000.0,
#     'IR e CS diferidos s/ resultados não realizados com hedge de fluxo de caixa': -12082000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': 639000.0,
#     'Resultado Abrangente Consolidado do Período': 161458000.0,
#     'Atribuído a Sócios da Empresa Controladora': 160943000.0,
#     'Atribuído a Sócios Não Controladores': 515000.0}},
#   'Demonstração do Fluxo de Caixa': {'01/01/2023\xa0\xa0a\xa0\xa030/09/2023': {'Caixa Líquido Atividades Operacionais': 158038000.0,
#     'Caixa Gerado nas Operações': 209186000.0,
#     'Lucro líquido do período': 94003000.0,
#     'Resultado atuarial de planos de pensão e saúde': 5770000.0,
#     'Resultado de participações em investidas por equivalência patrimonial': 1137000.0,
#     'Depreciação, depleção e amortização': 48223000.0,
#     'Perda (reversão) no valor de recuperação de ativos - Impairment': 2348000.0,
#     'Baixa de poços': 2031000.0,
#     'Perdas com processos judiciais, administrativos e arbitrais': 3369000.0,
#     'Variações cambiais, monetárias e encargos financeiros não realizados': 14157000.0,
#     'Imposto de renda e contrib. soc. dif. líquidos': 0.0,
#     'Perdas (reversões) de crédito esperadas': 247000.0,
#     'Ajuste a valor realizável líquido': -26000.0,
#     'Realização do ajuste acumulado de conversão e outros resultados abrangentes': 0.0,
#     'Revisão e atualização financeira de desmantelamento de áreas': 3314000.0,
#     'Realização do Hedge de Fluxo de Caixa por venda de participação societária': 0.0,
#     'Imposto de renda e contribuição social': 42482000.0,
#     'Resultado com acordo de coparticipação em áreas licitadas': -236000.0,
#     'Resultado com alienações e baixa de ativos': -5811000.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Encerramento antecipado e alterações em pagamentos de contratos de arrendamento': -1822000.0,
#     'Assunção de participação em concessões': 0.0,
#     'Variações nos Ativos e Passivos': -12193000.0,
#     'Contas a receber': 3038000.0,
#     'Estoques': 5866000.0,
#     'Depósitos judiciais': -5525000.0,
#     'Depósitos vinculados a Class Action': 0.0,
#     'Outros ativos': 865000.0,
#     'Fornecedores': -5050000.0,
#     'Impostos e contribuições': -2134000.0,
#     'Planos de pensão e de saúde': -3405000.0,
#     'Provisão para processos judiciais e administrativos': -1822000.0,
#     'Outros benefícios a empregados': 767000.0,
#     'Ganhos/perda na remensuração - Participações societárias': 0.0,
#     'Provisão para desmantelamento de áreas': -2980000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': -1813000.0,
#     'Operações descontinuadas-Recursos líquidos gerados pelas atividades operacionais': 0.0,
#     'Outros': -38955000.0,
#     'Imposto de renda e contribuição social pagos': -38955000.0,
#     'Caixa Líquido Atividades de Investimento': -23518000.0,
#     'Aquisições de ativos imobilizados e intangíveis': -42521000.0,
#     'Aquisição de participações societárias': -110000.0,
#     'Recebimentos pela venda de ativos - Desinvestimentos': 18025000.0,
#     '(Investimentos) resgates em títulos e valores mobiliários': -1319000.0,
#     'Dividendos recebidos': 375000.0,
#     'Aquisição de direito exploratório do Excedente de Cessão Onerosa': 0.0,
#     'Revisão Cessão Onerosa': 0.0,
#     'Compensação financeira por Acordos de Coparticipação': 2032000.0,
#     'Operações descontinuadas-Recursos líquidos gerados nas atividades de investimentos': 0.0,
#     'Caixa Líquido Atividades de Financiamento': -114507000.0,
#     'Participação de acionistas não controladores': -516000.0,
#     'Captações': 6257000.0,
#     'Amortizações de principal - financiamentos': -12467000.0,
#     'Amortizações de juros - financiamentos': -7882000.0,
#     'Dividendos pagos a acionistas da Petrobras': -76201000.0,
#     'Dividendos pagos a acionistas não controladores': -249000.0,
#     'Recebimentos pela venda de participação acionária sem perda de controle': 0.0,
#     'Amortizações de arrendamentos': -22474000.0,
#     'Operações descontinuadas-Recursos líquidos utilizados pelas atividades de financiamentos': 0.0,
#     'Recompra de ações': -975000.0,
#     'Variação Cambial s/ Caixa e Equivalentes': -1094000.0,
#     'Aumento (Redução) de Caixa e Equivalentes': 18919000.0,
#     'Saldo Inicial de Caixa e Equivalentes': 41723000.0,
#     'Saldo Final de Caixa e Equivalentes': 60642000.0},
#    '01/01/2022\xa0\xa0a\xa0\xa030/09/2022': {'Caixa Líquido Atividades Operacionais': 187835000.0,
#     'Caixa Gerado nas Operações': 279706000.0,
#     'Lucro líquido do período': 145503000.0,
#     'Resultado atuarial de planos de pensão e saúde': 4815000.0,
#     'Resultado de participações em investidas por equivalência patrimonial': -1933000.0,
#     'Depreciação, depleção e amortização': 50743000.0,
#     'Perda (reversão) no valor de recuperação de ativos - Impairment': 2179000.0,
#     'Baixa de poços': 632000.0,
#     'Perdas com processos judiciais, administrativos e arbitrais': 4169000.0,
#     'Variações cambiais, monetárias e encargos financeiros não realizados': 23876000.0,
#     'Imposto de renda e contrib. soc. dif. líquidos': 0.0,
#     'Perdas (reversões) de crédito esperadas': 213000.0,
#     'Ajuste a valor realizável líquido': 34000.0,
#     'Realização do ajuste acumulado de conversão e outros resultados abrangentes': 0.0,
#     'Revisão e atualização financeira de desmantelamento de áreas': 2172000.0,
#     'Realização do Hedge de Fluxo de Caixa por venda de participação societária': 0.0,
#     'Imposto de renda e contribuição social': 70194000.0,
#     'Resultado com acordo de coparticipação em áreas licitadas': -14193000.0,
#     'Resultado com alienações e baixa de ativos': -5850000.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Encerramento antecipado e alterações em pagamentos de contratos de arrendamento': -2848000.0,
#     'Assunção de participação em concessões': 0.0,
#     'Variações nos Ativos e Passivos': -47010000.0,
#     'Contas a receber': 3823000.0,
#     'Estoques': -13259000.0,
#     'Depósitos judiciais': -6760000.0,
#     'Depósitos vinculados a Class Action': 0.0,
#     'Outros ativos': -3483000.0,
#     'Fornecedores': -2140000.0,
#     'Impostos e contribuições': -12679000.0,
#     'Planos de pensão e de saúde': -9666000.0,
#     'Provisão para processos judiciais e administrativos': -1292000.0,
#     'Outros benefícios a empregados': -184000.0,
#     'Ganhos/perda na remensuração - Participações societárias': 0.0,
#     'Provisão para desmantelamento de áreas': -2285000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': 915000.0,
#     'Operações descontinuadas-Recursos líquidos gerados pelas atividades operacionais': 0.0,
#     'Outros': -44861000.0,
#     'Imposto de renda e contribuição social pagos': -44861000.0,
#     'Caixa Líquido Atividades de Investimento': 7921000.0,
#     'Aquisições de ativos imobilizados e intangíveis': -30946000.0,
#     'Aquisição de participações societárias': -101000.0,
#     'Recebimentos pela venda de ativos - Desinvestimentos': 19927000.0,
#     '(Investimentos) resgates em títulos e valores mobiliários': -8055000.0,
#     'Dividendos recebidos': 1615000.0,
#     'Aquisição de direito exploratório do Excedente de Cessão Onerosa': 0.0,
#     'Revisão Cessão Onerosa': 0.0,
#     'Compensação financeira por Acordos de Coparticipação': 25481000.0,
#     'Operações descontinuadas-Recursos líquidos gerados nas atividades de investimentos': 0.0,
#     'Caixa Líquido Atividades de Financiamento': -227173000.0,
#     'Participação de acionistas não controladores': 241000.0,
#     'Captações': 13322000.0,
#     'Amortizações de principal - financiamentos': -39255000.0,
#     'Amortizações de juros - financiamentos': -7499000.0,
#     'Dividendos pagos a acionistas da Petrobras': -173075000.0,
#     'Dividendos pagos a acionistas não controladores': -340000.0,
#     'Recebimentos pela venda de participação acionária sem perda de controle': 0.0,
#     'Amortizações de arrendamentos': -20567000.0,
#     'Operações descontinuadas-Recursos líquidos utilizados pelas atividades de financiamentos': 0.0,
#     'Recompra de ações': 0.0,
#     'Variação Cambial s/ Caixa e Equivalentes': -3415000.0,
#     'Aumento (Redução) de Caixa e Equivalentes': -34832000.0,
#     'Saldo Inicial de Caixa e Equivalentes': 58482000.0,
#     'Saldo Final de Caixa e Equivalentes': 23650000.0}},
#   'Demonstração de Valor Adicionado': {'01/01/2023\xa0\xa0a\xa0\xa030/09/2023': {'Receitas': 509361000.0,
#     'Vendas de Mercadorias, Produtos e Serviços': 447624000.0,
#     'Outras Receitas': 18497000.0,
#     'Receitas refs. à Construção de Ativos Próprios': 43487000.0,
#     'Provisão/Reversão de Créds. Liquidação Duvidosa': -247000.0,
#     'Insumos Adquiridos de Terceiros': -177814000.0,
#     'Custos Prods., Mercs. e Servs. Vendidos': -71332000.0,
#     'Materiais, Energia, Servs. de Terceiros e Outros': -77242000.0,
#     'Perda/Recuperação de Valores Ativos': -2348000.0,
#     'Outros': -26892000.0,
#     'Créditos fiscais sobre insumos adquiridos de terceiros': -26918000.0,
#     'Ajuste a valor realizável líquido': 26000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Valor Adicionado Bruto': 331547000.0,
#     'Retenções': -55526000.0,
#     'Depreciação, Amortização e Exaustão': -55526000.0,
#     'Outras': 0.0,
#     'Valor Adicionado Líquido Produzido': 276021000.0,
#     'Vlr Adicionado Recebido em Transferência': 9128000.0,
#     'Resultado de Equivalência Patrimonial': -1137000.0,
#     'Receitas Financeiras': 7906000.0,
#     'Outros1': 2359000.0,
#     'Aluguéis, royalties e outros': 2359000.0,
#     'Valor adicionado total a distribuir das operações descontinuadas': 0.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Valor Adicionado Total a Distribuir': 285149000.0,
#     'Distribuição do Valor Adicionado': 285149000.0,
#     'Pessoal': 23994000.0,
#     'Remuneração Direta': 15558000.0,
#     'Benefícios': 7612000.0,
#     'F.G.T.S.': 824000.0,
#     'Outros2': 0.0,
#     'Impostos, Taxas e Contribuições': 136306000.0,
#     'Federais': 102215000.0,
#     'Estaduais': 33566000.0,
#     'Municipais': 525000.0,
#     'Remuneração de Capitais de Terceiros': 30846000.0,
#     'Juros': 25767000.0,
#     'Aluguéis': 5079000.0,
#     'Outras1': 0.0,
#     'Remuneração de Capitais Próprios': 94003000.0,
#     'Juros sobre o Capital Próprio': 13617000.0,
#     'Dividendos': 26303000.0,
#     'Lucros Retidos / Prejuízo do Período': 53643000.0,
#     'Part. Não Controladores nos Lucros Retidos': 440000.0,
#     'Outros3': 0.0,
#     'Valor adicionado total distribuído das operações descontinuadas': 0.0},
#    '01/01/2022\xa0\xa0a\xa0\xa030/09/2022': {'Receitas': 618833000.0,
#     'Vendas de Mercadorias, Produtos e Serviços': 565117000.0,
#     'Outras Receitas': 26078000.0,
#     'Receitas refs. à Construção de Ativos Próprios': 27851000.0,
#     'Provisão/Reversão de Créds. Liquidação Duvidosa': -213000.0,
#     'Insumos Adquiridos de Terceiros': -187371000.0,
#     'Custos Prods., Mercs. e Servs. Vendidos': -112116000.0,
#     'Materiais, Energia, Servs. de Terceiros e Outros': -39018000.0,
#     'Perda/Recuperação de Valores Ativos': -2179000.0,
#     'Outros': -34058000.0,
#     'Créditos fiscais sobre insumos adquiridos de terceiros': -34024000.0,
#     'Ajuste a valor realizável líquido': -34000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Valor Adicionado Bruto': 431462000.0,
#     'Retenções': -55658000.0,
#     'Depreciação, Amortização e Exaustão': -55658000.0,
#     'Outras': 0.0,
#     'Valor Adicionado Líquido Produzido': 375804000.0,
#     'Vlr Adicionado Recebido em Transferência': 11650000.0,
#     'Resultado de Equivalência Patrimonial': 1933000.0,
#     'Receitas Financeiras': 7127000.0,
#     'Outros1': 2590000.0,
#     'Aluguéis, royalties e outros': 2590000.0,
#     'Valor adicionado total a distribuir das operações descontinuadas': 0.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Valor Adicionado Total a Distribuir': 387454000.0,
#     'Distribuição do Valor Adicionado': 387454000.0,
#     'Pessoal': 21856000.0,
#     'Remuneração Direta': 14215000.0,
#     'Benefícios': 6896000.0,
#     'F.G.T.S.': 745000.0,
#     'Outros2': 0.0,
#     'Impostos, Taxas e Contribuições': 183211000.0,
#     'Federais': 148842000.0,
#     'Estaduais': 33838000.0,
#     'Municipais': 531000.0,
#     'Remuneração de Capitais de Terceiros': 36884000.0,
#     'Juros': 31906000.0,
#     'Aluguéis': 4978000.0,
#     'Outras1': 0.0,
#     'Remuneração de Capitais Próprios': 145503000.0,
#     'Juros sobre o Capital Próprio': 11451000.0,
#     'Dividendos': 82664000.0,
#     'Lucros Retidos / Prejuízo do Período': 50872000.0,
#     'Part. Não Controladores nos Lucros Retidos': 516000.0,
#     'Outros3': 0.0,
#     'Valor adicionado total distribuído das operações descontinuadas': 0.0}}},
#  '2023-06-30': {'Balanço Patrimonial Ativo': {'01/01/2023  a  31/12/2023': {'Ativo Total': 990459000.0,
#     'Ativo Circulante': 136816000.0,
#     'Caixa e Equivalentes de Caixa': 49882000.0,
#     'Aplicações Financeiras': 11103000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0,
#     'Títulos para Negociação': 0.0,
#     'Títulos Designados a Valor Justo': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0,
#     'Contas a Receber': 21041000.0,
#     'Clientes': 0.0,
#     'Outras Contas a Receber': 0.0,
#     'Estoques': 39241000.0,
#     'Ativos Biológicos': 0.0,
#     'Tributos a Recuperar': 6353000.0,
#     'Tributos Correntes a Recuperar': 6353000.0,
#     'Imposto de renda e contribuição social correntes': 977000.0,
#     'Impostos e contribuições': 5376000.0,
#     'Despesas Antecipadas': 0.0,
#     'Outros Ativos Circulantes': 9196000.0,
#     'Ativos Não-Correntes a Venda': 1937000.0,
#     'Ativos de Operações Descontinuadas': 0.0,
#     'Outros': 7259000.0,
#     'Depósitos Vinculados a Class Action': 0.0,
#     'Adiantamento a fornecedores': 0.0,
#     'Outros ativos': 7259000.0,
#     'Ativo Não Circulante': 853643000.0,
#     'Ativo Realizável a Longo Prazo': 122754000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado1': 0.0,
#     'Títulos Designados a Valor Justo1': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes1': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado1': 15384000.0,
#     'Contas a Receber1': 9651000.0,
#     'Clientes1': 0.0,
#     'Outras Contas a Receber1': 0.0,
#     'Estoques1': 0.0,
#     'Ativos Biológicos1': 0.0,
#     'Tributos Diferidos': 23810000.0,
#     'Imposto de renda e contribuição social diferidos': 3233000.0,
#     'Impostos e contribuições1': 20577000.0,
#     'Despesas Antecipadas1': 0.0,
#     'Créditos com Partes Relacionadas': 0.0,
#     'Créditos com Coligadas': 0.0,
#     'Créditos com Controladores': 0.0,
#     'Créditos com Outras Partes Relacionadas': 0.0,
#     'Outros Ativos Não Circulantes': 73909000.0,
#     'Ativos Não-Correntes a Venda1': 0.0,
#     'Ativos de Operações Descontinuadas1': 0.0,
#     'Adiantamento a fornecedores1': 0.0,
#     'Depósitos judiciais': 64265000.0,
#     'Outros ativos1': 9644000.0,
#     'Investimentos': 7921000.0,
#     'Participações Societárias': 0.0,
#     'Participações em Coligadas': 0.0,
#     'Participações em Controladas em Conjunto': 0.0,
#     'Outros Investimentos': 0.0,
#     'Propriedades para Investimento': 0.0,
#     'Imobilizado': 706647000.0,
#     'Imobilizado em Operação': 0.0,
#     'Direito de Uso em Arrendamento': 0.0,
#     'Imobilizado em Andamento': 0.0,
#     'Intangível': 16321000.0,
#     'Intangíveis': 0.0,
#     'Contrato de Concessão': 0.0,
#     'Goodwill': 0.0},
#    '01/01/2022  a  31/12/2022': {'Ativo Total': 976709000.0,
#     'Ativo Circulante': 163052000.0,
#     'Caixa e Equivalentes de Caixa': 41723000.0,
#     'Aplicações Financeiras': 14470000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0,
#     'Títulos para Negociação': 0.0,
#     'Títulos Designados a Valor Justo': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0,
#     'Contas a Receber': 26142000.0,
#     'Clientes': 0.0,
#     'Outras Contas a Receber': 0.0,
#     'Estoques': 45804000.0,
#     'Ativos Biológicos': 0.0,
#     'Tributos a Recuperar': 6819000.0,
#     'Tributos Correntes a Recuperar': 6819000.0,
#     'Imposto de renda e contribuição social correntes': 859000.0,
#     'Impostos e contribuições': 5960000.0,
#     'Despesas Antecipadas': 0.0,
#     'Outros Ativos Circulantes': 28094000.0,
#     'Ativos Não-Correntes a Venda': 18823000.0,
#     'Ativos de Operações Descontinuadas': 0.0,
#     'Outros': 9271000.0,
#     'Depósitos Vinculados a Class Action': 0.0,
#     'Adiantamento a fornecedores': 0.0,
#     'Outros ativos': 9271000.0,
#     'Ativo Não Circulante': 813657000.0,
#     'Ativo Realizável a Longo Prazo': 110722000.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado1': 0.0,
#     'Títulos Designados a Valor Justo1': 0.0,
#     'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes1': 0.0,
#     'Aplicações Financeiras Avaliadas ao Custo Amortizado1': 8159000.0,
#     'Contas a Receber1': 12729000.0,
#     'Clientes1': 0.0,
#     'Outras Contas a Receber1': 0.0,
#     'Estoques1': 0.0,
#     'Ativos Biológicos1': 0.0,
#     'Tributos Diferidos': 24057000.0,
#     'Imposto de renda e contribuição social diferidos': 4342000.0,
#     'Impostos e contribuições1': 19715000.0,
#     'Despesas Antecipadas1': 0.0,
#     'Créditos com Partes Relacionadas': 0.0,
#     'Créditos com Coligadas': 0.0,
#     'Créditos com Controladores': 0.0,
#     'Créditos com Outras Partes Relacionadas': 0.0,
#     'Outros Ativos Não Circulantes': 65777000.0,
#     'Ativos Não-Correntes a Venda1': 0.0,
#     'Ativos de Operações Descontinuadas1': 0.0,
#     'Adiantamento a fornecedores1': 0.0,
#     'Depósitos judiciais': 57671000.0,
#     'Outros ativos1': 8106000.0,
#     'Investimentos': 8172000.0,
#     'Participações Societárias': 0.0,
#     'Participações em Coligadas': 0.0,
#     'Participações em Controladas em Conjunto': 0.0,
#     'Outros Investimentos': 0.0,
#     'Propriedades para Investimento': 0.0,
#     'Imobilizado': 679182000.0,
#     'Imobilizado em Operação': 0.0,
#     'Direito de Uso em Arrendamento': 0.0,
#     'Imobilizado em Andamento': 0.0,
#     'Intangível': 15581000.0,
#     'Intangíveis': 0.0,
#     'Contrato de Concessão': 0.0,
#     'Goodwill': 0.0}},
#   'Balanço Patrimonial Passivo': {'01/01/2023  a  31/12/2023': {'Passivo Total': 990459000.0,
#     'Passivo Circulante': 151599000.0,
#     'Obrigações Sociais e Trabalhistas': 6843000.0,
#     'Obrigações Sociais': 0.0,
#     'Obrigações Trabalhistas': 0.0,
#     'Fornecedores': 26168000.0,
#     'Fornecedores Nacionais': 0.0,
#     'Fornecedores Estrangeiros': 0.0,
#     'Obrigações Fiscais': 2746000.0,
#     'Obrigações Fiscais Federais': 2746000.0,
#     'Imposto de Renda e Contribuição Social a Pagar': 2746000.0,
#     'Obrigações Fiscais Estaduais': 0.0,
#     'Obrigações Fiscais Municipais': 0.0,
#     'Empréstimos e Financiamentos': 49818000.0,
#     'Empréstimos e Financiamentos1': 19897000.0,
#     'Em Moeda Nacional': 0.0,
#     'Em Moeda Estrangeira': 0.0,
#     'Debêntures': 0.0,
# ...
#     'Resultado Antes dos Tributos sobre o Lucro': 151575000.0,
#     'Imposto de Renda e Contribuição Social sobre o Lucro': -44311000.0,
#     'Corrente': -22667000.0,
#     'Diferido': -21644000.0,
#     'Resultado Líquido das Operações Continuadas': 107264000.0,
#     'Resultado Líquido de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Líquido das Operações Descontinuadas': 0.0,
#     'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas': 0.0,
#     'Lucro/Prejuízo Consolidado do Período': 107264000.0,
#     'Atribuído a Sócios da Empresa Controladora': 106668000.0,
#     'Atribuído a Sócios Não Controladores': 596000.0,
#     'Lucro por Ação - (Reais / Ação)': 0.0,
#     'Lucro Básico por Ação': 0.0,
#     'ON': 8.18,
#     'PN': 8.18,
#     'Lucro Diluído por Ação': 0.0,
#     'ON1': 8.18,
#     'PN1': 8.18}},
#   'Demonstração do Resultado Abrangente': {'01/01/2022\xa0\xa0a\xa0\xa031/12/2022': {'Lucro Líquido Consolidado do Período': 189005000.0,
#     'Outros Resultados Abrangentes': 10940000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': -8297000.0,
#     'Imposto de renda e contribuição social diferidos s/ ganhos (perdas) atuariais com planos de benefíci': 1109000.0,
#     'Ajustes de conversão em investidas': -18366000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': 28359000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 25174000.0,
#     'Imposto de renda e contribuição social diferidos s/ resultados não realizados com hedge de fluxo de': -18201000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': 1162000.0,
#     'Resultado Abrangente Consolidado do Período': 199945000.0,
#     'Atribuído a Sócios da Empresa Controladora': 199270000.0,
#     'Atribuído a Sócios Não Controladores': 675000.0},
#    '01/01/2021\xa0\xa0a\xa0\xa031/12/2021': {'Lucro Líquido Consolidado do Período': 107264000.0,
#     'Outros Resultados Abrangentes': 41854000.0,
#     'Ganhos (Perdas) atuariais com planos de benefícios definidos': 27735000.0,
#     'Imposto de renda e contribuição social diferidos s/ ganhos (perdas) atuariais com planos de benefíci': -7207000.0,
#     'Ajustes de conversão em investidas': 19223000.0,
#     'Resultados não realizados com títulos patrimoniais mensurados a valor justo reconhecidos no PL': 0.0,
#     'Result ñ realiz em títulos mensurados vlr justo por meio de outros result abrangentes-transf result': 0.0,
#     'Imposto de renda e contribuição social diferidos s/ títulos patrimoniais mensurados a valor justo': 0.0,
#     'Resultados não realizados com hedge de fluxo de caixa reconhecidos no PL': -21754000.0,
#     'Hedge de fluxo de caixa transferido para o resultado': 24777000.0,
#     'Imposto de renda e contribuição social diferidos s/ resultados não realizados com hedge de fluxo de': -1028000.0,
#     'Equivalência patrimonial sobre outros resultados abrangentes em investidas': 108000.0,
#     'Resultado Abrangente Consolidado do Período': 149118000.0,
#     'Atribuído a Sócios da Empresa Controladora': 148207000.0,
#     'Atribuído a Sócios Não Controladores': 911000.0}},
#   'Demonstração do Fluxo de Caixa': {'01/01/2022\xa0\xa0a\xa0\xa031/12/2022': {'Caixa Líquido Atividades Operacionais': 255410000.0,
#     'Caixa Gerado nas Operações': 362138000.0,
#     'Lucro líquido do exercício': 189005000.0,
#     'Resultado atuarial de planos de pensão e saúde': 6333000.0,
#     'Resultado de participações em investidas por equivalência patrimonial': -1291000.0,
#     'Depreciação, depleção e amortização': 68202000.0,
#     'Perda (reversão) no valor de recuperação de ativos - Impairment': 6859000.0,
#     'Baixa de poços secos': 3584000.0,
#     'Perdas com processos judiciais, administrativos e arbitrais': 7011000.0,
#     'Variações cambiais,monetárias e encargos financeiros não realizados': 22956000.0,
#     'Imposto de Renda e Contrib. Soc. Dif. Líquidos': 0.0,
#     'Perdas (reversões) de crédito esperadas': 331000.0,
#     'Ajuste a valor de mercado dos estoques': 57000.0,
#     'Realização do ajuste acumulado de conversão e outros resultados abrangentes': 0.0,
#     'Revisão e atualização financeira de desmantelamento de áreas': 3858000.0,
#     'Realização do Hedge de Fluxo de Caixa por venda de participação societária': 0.0,
#     'Imposto de renda e contribuição social': 85993000.0,
#     'Resultado com acordo de coparticipação em áreas licitadas': -21660000.0,
#     'Result.c/alienações, baixa ativos, remensuração e realiz. result.abrangentes por alienação part.soc.': -5883000.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Encerramento antecipado e alterações em pagamentos de contratos de arrendamento': -3217000.0,
#     'Assunção de participação em concessões': 0.0,
#     'Variações nos Ativos e Passivos': -47581000.0,
#     'Contas a receber': 1891000.0,
#     'Estoques': -6029000.0,
#     'Depósitos judiciais': -8844000.0,
#     'Depósitos vinculados a Class Action': 0.0,
#     'Outros ativos': -1675000.0,
#     'Fornecedores': -2223000.0,
#     'Impostos e contribuições': -12903000.0,
#     'Planos de pensão e de saúde': -11035000.0,
#     'Provisão para processos judiciais e administrativos': -1956000.0,
#     'Salários, férias, encargos e participações': -808000.0,
#     'Imposto de renda e contribuição social pagos': 0.0,
#     'Provisão para desmantelamento de áreas': -3123000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': -876000.0,
#     'Operações descontinuadas-Recursos líquidos gerados pelas atividades operacionais': 0.0,
#     'Outros': -59147000.0,
#     'Imposto de renda e contribuição social pagos1': -59147000.0,
#     'Caixa Líquido Atividades de Investimento': -4377000.0,
#     'Aquisições de ativos imobilizados e intangíveis': -49656000.0,
#     'Reduções (adições) em investimentos': -138000.0,
#     'Recebimentos pela venda de ativos - Desinvestimentos': 24815000.0,
#     '(Investimentos) resgates em títulos e valores mobiliários': -17072000.0,
#     'Dividendos recebidos': 1905000.0,
#     'Aquisição de direito exploratório do Excedente de Cessão Onerosa': 0.0,
#     'Revisão Cessão Onerosa': 0.0,
#     'Compensação financeira por Acordos de Coparticipação': 35769000.0,
#     'Operações descontinuadas-Recursos líquidos gerados nas atividades de investimentos': 0.0,
#     'Caixa Líquido Atividades de Financiamento': -264156000.0,
#     'Participação de acionistas não controladores': 347000.0,
#     'Captações': 15156000.0,
#     'Amortizações de principal - financiamentos': -47337000.0,
#     'Amortizações de juros - financiamentos': -9664000.0,
#     'Dividendos pagos a acionistas da Petrobras': -194200000.0,
#     'Dividendos pagos a acionistas não controladores': -409000.0,
#     'Recebimentos pela venda de participação acionária sem perda de controle': 0.0,
#     'Amortizações de arrendamentos': -28049000.0,
#     'Operações descontinuadas-Recursos líquidos utilizados pelas atividades de financiamentos': 0.0,
#     'Variação Cambial s/ Caixa e Equivalentes': -3636000.0,
#     'Aumento (Redução) de Caixa e Equivalentes': -16759000.0,
#     'Saldo Inicial de Caixa e Equivalentes': 58482000.0,
#     'Saldo Final de Caixa e Equivalentes': 41723000.0},
#    '01/01/2021\xa0\xa0a\xa0\xa031/12/2021': {'Caixa Líquido Atividades Operacionais': 203126000.0,
#     'Caixa Gerado nas Operações': 244712000.0,
#     'Lucro líquido do exercício': 107264000.0,
#     'Resultado atuarial de planos de pensão e saúde': 11215000.0,
#     'Resultado de participações em investidas por equivalência patrimonial': -8427000.0,
#     'Depreciação, depleção e amortização': 63048000.0,
#     'Perda (reversão) no valor de recuperação de ativos - Impairment': -16890000.0,
#     'Baixa de poços secos': 1365000.0,
#     'Perdas com processos judiciais, administrativos e arbitrais': 3887000.0,
#     'Variações cambiais,monetárias e encargos financeiros não realizados': 58391000.0,
#     'Imposto de Renda e Contrib. Soc. Dif. Líquidos': 0.0,
#     'Perdas (reversões) de crédito esperadas': -187000.0,
#     'Ajuste a valor de mercado dos estoques': 6000.0,
#     'Realização do ajuste acumulado de conversão e outros resultados abrangentes': 0.0,
#     'Revisão e atualização financeira de desmantelamento de áreas': 3529000.0,
#     'Realização do Hedge de Fluxo de Caixa por venda de participação societária': 0.0,
#     'Imposto de renda e contribuição social': 44311000.0,
#     'Resultado com acordo de coparticipação em áreas licitadas': -3317000.0,
#     'Result.c/alienações, baixa ativos, remensuração e realiz. result.abrangentes por alienação part.soc.': -10669000.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': -4966000.0,
#     'Encerramento antecipado e alterações em pagamentos de contratos de arrendamento': -2960000.0,
#     'Assunção de participação em concessões': -888000.0,
#     'Variações nos Ativos e Passivos': -29935000.0,
#     'Contas a receber': -10783000.0,
#     'Estoques': -12651000.0,
#     'Depósitos judiciais': -6165000.0,
#     'Depósitos vinculados a Class Action': 0.0,
#     'Outros ativos': -1752000.0,
#     'Fornecedores': 5667000.0,
#     'Impostos e contribuições': 14885000.0,
#     'Planos de pensão e de saúde': -11848000.0,
#     'Provisão para processos judiciais e administrativos': -3517000.0,
#     'Salários, férias, encargos e participações': -1777000.0,
#     'Imposto de renda e contribuição social pagos': 0.0,
#     'Provisão para desmantelamento de áreas': -3935000.0,
#     'Acordo com autoridades norte americanas': 0.0,
#     'Outros passivos': 1941000.0,
#     'Operações descontinuadas-Recursos líquidos gerados pelas atividades operacionais': 0.0,
#     'Outros': -11651000.0,
#     'Imposto de renda e contribuição social pagos1': -11651000.0,
#     'Caixa Líquido Atividades de Investimento': 11073000.0,
#     'Aquisições de ativos imobilizados e intangíveis': -34134000.0,
#     'Reduções (adições) em investimentos': -129000.0,
#     'Recebimentos pela venda de ativos - Desinvestimentos': 25494000.0,
#     '(Investimentos) resgates em títulos e valores mobiliários': -1000.0,
#     'Dividendos recebidos': 4333000.0,
#     'Aquisição de direito exploratório do Excedente de Cessão Onerosa': 0.0,
#     'Revisão Cessão Onerosa': 0.0,
#     'Compensação financeira por Acordos de Coparticipação': 15510000.0,
#     'Operações descontinuadas-Recursos líquidos gerados nas atividades de investimentos': 0.0,
#     'Caixa Líquido Atividades de Financiamento': -220297000.0,
#     'Participação de acionistas não controladores': -122000.0,
#     'Captações': 9647000.0,
#     'Amortizações de principal - financiamentos': -113549000.0,
#     'Amortizações de juros - financiamentos': -12155000.0,
#     'Dividendos pagos a acionistas da Petrobras': -72153000.0,
#     'Dividendos pagos a acionistas não controladores': -565000.0,
#     'Recebimentos pela venda de participação acionária sem perda de controle': 0.0,
#     'Amortizações de arrendamentos': -31400000.0,
#     'Operações descontinuadas-Recursos líquidos utilizados pelas atividades de financiamentos': 0.0,
#     'Variação Cambial s/ Caixa e Equivalentes': 3650000.0,
#     'Aumento (Redução) de Caixa e Equivalentes': -2448000.0,
#     'Saldo Inicial de Caixa e Equivalentes': 60930000.0,
#     'Saldo Final de Caixa e Equivalentes': 58482000.0}},
#   'Demonstração de Valor Adicionado': {'01/01/2022\xa0\xa0a\xa0\xa031/12/2022': {'Receitas': 819670000.0,
#     'Vendas de Mercadorias, Produtos e Serviços': 742671000.0,
#     'Outras Receitas': 35897000.0,
#     'Receitas refs. à Construção de Ativos Próprios': 41433000.0,
#     'Provisão/Reversão de Créds. Liquidação Duvidosa': -331000.0,
#     'Insumos Adquiridos de Terceiros': -275987000.0,
#     'Custos Prods., Mercs. e Servs. Vendidos': -148429000.0,
#     'Materiais, Energia, Servs. de Terceiros e Outros': -74930000.0,
#     'Perda/Recuperação de Valores Ativos': -6859000.0,
#     'Outros': -45769000.0,
#     'Créditos fiscais sobre insumos adquiridos de terceiros': -45712000.0,
#     'Ajuste a valor de mercado dos estoques': -57000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Valor Adicionado Bruto': 543683000.0,
#     'Retenções': -75121000.0,
#     'Depreciação, Amortização e Exaustão': -75121000.0,
#     'Outras': 0.0,
#     'Valor Adicionado Líquido Produzido': 468562000.0,
#     'Vlr Adicionado Recebido em Transferência': 14483000.0,
#     'Resultado de Equivalência Patrimonial': 1291000.0,
#     'Receitas Financeiras': 9420000.0,
#     'Outros1': 3772000.0,
#     'Aluguéis, royalties e outros': 3772000.0,
#     'Valor adicionado total a distribuir das operações descontinuadas': 0.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 0.0,
#     'Valor Adicionado Total a Distribuir': 483045000.0,
#     'Distribuição do Valor Adicionado': 483045000.0,
#     'Pessoal': 29191000.0,
#     'Remuneração Direta': 19078000.0,
#     'Benefícios': 9034000.0,
#     'F.G.T.S.': 1079000.0,
#     'Outros2': 0.0,
#     'Impostos, Taxas e Contribuições': 224836000.0,
#     'Federais': 182981000.0,
#     'Estaduais': 41040000.0,
#     'Municipais': 815000.0,
#     'Remuneração de Capitais de Terceiros': 40013000.0,
#     'Juros': 33951000.0,
#     'Aluguéis': 6062000.0,
#     'Outras1': 0.0,
#     'Remuneração de Capitais Próprios': 189005000.0,
#     'Juros sobre o Capital Próprio': 19589000.0,
#     'Dividendos': 155965000.0,
#     'Lucros Retidos / Prejuízo do Período': 12774000.0,
#     'Part. Não Controladores nos Lucros Retidos': 677000.0,
#     'Outros3': 0.0,
#     'Valor adicionado total a distribuído das operações descontinuadas': 0.0},
#    '01/01/2021\xa0\xa0a\xa0\xa031/12/2021': {'Receitas': 632646000.0,
#     'Vendas de Mercadorias, Produtos e Serviços': 567449000.0,
#     'Outras Receitas': 30325000.0,
#     'Receitas refs. à Construção de Ativos Próprios': 34685000.0,
#     'Provisão/Reversão de Créds. Liquidação Duvidosa': 187000.0,
#     'Insumos Adquiridos de Terceiros': -179566000.0,
#     'Custos Prods., Mercs. e Servs. Vendidos': -103370000.0,
#     'Materiais, Energia, Servs. de Terceiros e Outros': -55156000.0,
#     'Perda/Recuperação de Valores Ativos': 16890000.0,
#     'Outros': -37930000.0,
#     'Créditos fiscais sobre insumos adquiridos de terceiros': -37924000.0,
#     'Ajuste a valor de mercado dos estoques': -6000.0,
#     'Baixa de gastos adicionais capitalizados indevidamente': 0.0,
#     'Valor Adicionado Bruto': 453080000.0,
#     'Retenções': -69769000.0,
#     'Depreciação, Amortização e Exaustão': -69769000.0,
#     'Outras': 0.0,
#     'Valor Adicionado Líquido Produzido': 383311000.0,
#     'Vlr Adicionado Recebido em Transferência': 19795000.0,
#     'Resultado de Equivalência Patrimonial': 8427000.0,
#     'Receitas Financeiras': 4458000.0,
#     'Outros1': 6910000.0,
#     'Aluguéis, royalties e outros': 1948000.0,
#     'Valor adicionado total a distribuir das operações descontinuadas': 0.0,
#     'Recuperação de PIS e COFINS - Exclusão de ICMS na base de cálculo': 4962000.0,
#     'Valor Adicionado Total a Distribuir': 403106000.0,
#     'Distribuição do Valor Adicionado': 403106000.0,
#     'Pessoal': 32052000.0,
#     'Remuneração Direta': 17656000.0,
#     'Benefícios': 13393000.0,
#     'F.G.T.S.': 1003000.0,
#     'Outros2': 0.0,
#     'Impostos, Taxas e Contribuições': 186816000.0,
#     'Federais': 145335000.0,
#     'Estaduais': 40694000.0,
#     'Municipais': 787000.0,
#     'Remuneração de Capitais de Terceiros': 76974000.0,
#     'Juros': 71520000.0,
#     'Aluguéis': 5454000.0,
#     'Outras1': 0.0,
#     'Remuneração de Capitais Próprios': 107264000.0,
#     'Juros sobre o Capital Próprio': 13824000.0,
#     'Dividendos': 85828000.0,
#     'Lucros Retidos / Prejuízo do Período': 7016000.0,
#     'Part. Não Controladores nos Lucros Retidos': 596000.0,
#     'Outros3': 0.0,
#     'Valor adicionado total a distribuído das operações descontinuadas': 0.0}}}}
